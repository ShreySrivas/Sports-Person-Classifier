# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
im_path = 'C:/Users/yeshu/Projects/SportsPersonClassifier/datasets/lionel_messi/_111066400_messi.jpg'
img = cv2.imdecode(np.fromfile(im_path, dtype=np.uint8), cv2.IMREAD_UNCHANGED)
img.shape
plt.imshow(img)

# %%
img = cv2.imread('.datasets/maria_sharapova/maria-sharapova (1).jpg')

plt.imshow(img)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32932/273582653.py in <module>
#       1 img = cv2.imread('.datasets/maria_sharapova/maria-sharapova (1).jpg')
# ----> 2 plt.imshow(img)
#       3 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4 gray.shape
#       5
#
# ~\anaconda3\envs\mlenv\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2902         data=None, **kwargs):
# -> 2903     __ret = gca().imshow(
#    2904         X, cmap=cmap, norm=norm, aspect=aspect,
#    2905         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\envs\mlenv\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
